# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molmodmt as m3t
from simtk import unit
# Out:
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/yank-0.24.0-py3.7-linux-x86_64.egg/yank/experiment.py:1168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """)

# %%
system = m3t.load('pdb:1B3T','pdbfixer')

# %%
m3t.get(system, n_aminoacids=True, n_nucleotides=True, n_waters=True, n_ions=True)
# Out:
# [294, 36, 182, 0]

# %%
system = m3t.remove_solvent(system)

# %%
m3t.get(system, n_aminoacids=True, n_nucleotides=True, n_waters=True, n_ions=True)
# Out:
# [294, 36, 0, 0]

# %%
m3t.info(system, element='residues', selection='dna')
# Out:
#    Name  index  id  chain index molecule type
# 0    DG      0   0            0           dna
# 1    DG      1   1            0           dna
# 2    DG      2   2            0           dna
# 3    DA      3   3            0           dna
# 4    DA      4   4            0           dna
# 5    DG      5   5            0           dna
# 6    DC      6   6            0           dna
# 7    DA      7   7            0           dna
# 8    DT      8   8            0           dna
# 9    DA      9   9            0           dna
# 10   DT     10  10            0           dna
# 11   DG     11  11            0           dna
# 12   DC     12  12            0           dna
# 13   DT     13  13            0           dna
# 14   DT     14  14            0           dna
# 15   DC     15  15            0           dna
# 16   DC     16  16            0           dna
# 17   DC     17  17            0           dna
# 18   DG     18  18            1           dna
# ...

# %%
system2 = m3t.set(system, element='residues', indices=[0,17,18,35], residue_names=["A","B","C","D"] )

# %%
m3t.info(system2, element='residues', selection='all')

# %%
aa = list(system2.topology.bonds())

# %%
aa
# Out:
# [Bond(<Atom 7 (C1') of chain 0 residue 0 (A)>, <Atom 6 (C2') of chain 0 residue 0 (A)>),
#  Bond(<Atom 7 (C1') of chain 0 residue 0 (A)>, <Atom 8 (N9) of chain 0 residue 0 (A)>),
#  Bond(<Atom 7 (C1') of chain 0 residue 0 (A)>, <Atom 3 (O4') of chain 0 residue 0 (A)>),
#  Bond(<Atom 15 (C2) of chain 0 residue 0 (A)>, <Atom 14 (N1) of chain 0 residue 0 (A)>),
#  Bond(<Atom 15 (C2) of chain 0 residue 0 (A)>, <Atom 16 (N2) of chain 0 residue 0 (A)>),
#  Bond(<Atom 15 (C2) of chain 0 residue 0 (A)>, <Atom 17 (N3) of chain 0 residue 0 (A)>),
#  Bond(<Atom 6 (C2') of chain 0 residue 0 (A)>, <Atom 4 (C3') of chain 0 residue 0 (A)>),
#  Bond(<Atom 4 (C3') of chain 0 residue 0 (A)>, <Atom 2 (C4') of chain 0 residue 0 (A)>),
#  Bond(<Atom 4 (C3') of chain 0 residue 0 (A)>, <Atom 5 (O3') of chain 0 residue 0 (A)>),
#  Bond(<Atom 18 (C4) of chain 0 residue 0 (A)>, <Atom 11 (C5) of chain 0 residue 0 (A)>),
#  Bond(<Atom 18 (C4) of chain 0 residue 0 (A)>, <Atom 17 (N3) of chain 0 residue 0 (A)>),
# ...

# %%
aa[0].name

# %%
bb.index()

# %%
m3t.get(system, selection='not protein', residue_name=True)

# %%
m3t.get(system, selection='dna', n_residues=True, n_aminoacids=True, n_nucleotides=True, n_waters=True, n_ions=True)

# %%
system_fixed = m3t.fix_pdb_structure(system)

# %%
m3t.energy_minimization(system_fixed)

# %%
aa=list(system.topology.atoms())

# %%
system.topology.residues()

# %%
aa = "patata"

# %%
aa = "boa"

# %%
aa.replace("boa",'tururu')

# %%
def veo(aa=None, **kwargs):
    print(kwargs)

# %%
veo(aa=7, bb=324, cc='nada')

# %%
ccc = list(system.topology.residues())

# %%
ccc[0].chain.index
